# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani-2001-21/APL405/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone --branch dependabot/pip/scipy-1.10.0 https://github.com/zhampel/clusterGAN.git
# Out:
# fatal: destination path 'clusterGAN' already exists and is not an empty directory.

# %%
# %cd clusterGAN
# Out:
# /content/clusterGAN

# %%
# !pip install matplotlib>=3.5.0 tqdm seaborn scikit-learn>=1.0 scipy>=1.10.0 torch>=2.0.0 torchvision>=0.15.0 numpy>=1.21 pandas>=1.3

# %%
# !pip install -e /content/clusterGAN --ignore-requires-python --no-deps
# Out:
# Obtaining file:///content/clusterGAN
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for clusgan
# ...

# %%
# !python train.py -r test_run -s mnist -b 64 -n 300
# Out:
# Results to be saved in directory /content/clusterGAN/runs/mnist/300epoch_z30_van_bs64_test_run
#
#
# Begin training session with 300 epochs...
#
# /content/clusterGAN/clusgan/utils.py:81: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at /pytorch/torch/csrc/tensor/python_tensor.cpp:78.)
#   zn = Variable(Tensor(0.75*np.random.normal(0, 1, (shape, latent_dim))), requires_grad=req_grad)
# [Epoch 0/300]
# 	Model Losses: [D: 0.470196] [GE: 2.494272]
# 	Cycle Losses: [x: 0.045693] [z_n: 0.144466] [z_c: 0.005083]
# [Epoch 1/300]
# 	Model Losses: [D: 0.678846] [GE: 1.932784]
# 	Cycle Losses: [x: 0.047416] [z_n: 0.105549] [z_c: 0.000184]
# [Epoch 2/300]
# 	Model Losses: [D: 0.531387] [GE: 2.627842]
# 	Cycle Losses: [x: 0.044713] [z_n: 0.087984] [z_c: 0.000066]
# [Epoch 3/300]
# 	Model Losses: [D: 0.463980] [GE: 2.556004]
# ...

# %%
# !python gen-examples.py -r test_run -s mnist -b 100
# Out:
# usage: gen-examples.py [-h] [-r RUN_DIR] [-b BATCH_SIZE]
# gen-examples.py: error: unrecognized arguments: -s mnist

# %%
# !python tsne-cluster.py -r test_run -s mnist
# Out:
# usage: tsne-cluster.py [-h] [-r RUN_DIR] [-p PERPLEXITY] [-n N_SAMPLES]
# tsne-cluster.py: error: unrecognized arguments: -s mnist

# %%
# ! https://github.com/eriklindernoren/PyTorch-GAN
# !git clone  https://github.com/eriklindernoren/PyTorch-GAN
# Out:
# Cloning into 'PyTorch-GAN'...
# remote: Enumerating objects: 1283, done.
# remote: Total 1283 (delta 0), reused 0 (delta 0), pack-reused 1283 (from 1)
# Receiving objects: 100% (1283/1283), 68.04 MiB | 6.19 MiB/s, done.
# Resolving deltas: 100% (751/751), done.

# %%
# !cd /content/PyTorch-GAN/implementations
# !python3 /content/PyTorch-GAN/implementations/cluster_gan/cluster_gan_s.py
# Out:
# Begin training session with 200 epochs...
#
# Traceback (most recent call last):
#   File "/content/PyTorch-GAN/implementations/cluster_gan/cluster_gan_s.py", line 268, in <module>
#     for i, (imgs, _) in enumerate(dataloader):
#                         ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 734, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 790, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#             ~~~~~~~~~~~~^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torchvision/datasets/mnist.py", line 146, in __getitem__
# ...

# %%
from IPython.display import Image, display
display(Image('images/gen_000010.png'))

# %%
n_c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3321893580.py in <cell line: 0>()
# ----> 1 n_c
#
# NameError: name 'n_c' is not defined
